# %%
import pandas as pd

# %%
allopathic_data = pd.read_json('../../data/allopathicDrugData.json')

# %%
allopathic_data = allopathic_data.drop(0, axis=1)

# %%
allopathic_data
# Out:
#                                 1                              2  \
# 0          ACI HealthCare Limited                    Nimocon 500
# 1          ACI HealthCare Limited                          Adbon
# 2          ACI HealthCare Limited                     Opental 50
# 3          ACI HealthCare Limited                      Acidex 20
# 4          ACI HealthCare Limited                     Neutin 600
# ...                           ...                            ...
# 35090  Ziska Pharmaceuticals Ltd.                Esoprol 20 MUPS
# 35091  Ziska Pharmaceuticals Ltd.                Esoprol 40 MUPS
# 35092  Ziska Pharmaceuticals Ltd.   Tizaro2.5 Pre-filled Syringe
# 35093  Ziska Pharmaceuticals Ltd.    Tizaro 5 Pre-filled Syringe
# 35094  Ziska Pharmaceuticals Ltd.  Tizaro 7.5 Pre-filled Syringe
#
#                             3                4            5  6      7  \
# 0                Azithromycin           500 mg       Tablet  0  Human
# 1        Calcium + Vitamin D3  500 mg + 200 IU       Tablet  0  Human
# 2      Tramadol Hydrochloride            50 mg       Tablet  0  Human
# 3                  Omeprazole            20 mg      Capsule  0  Human
# 4                  Gabapentin           600 mg       Tablet  0  Human
# ...                       ...              ...          ... ..    ...
# 35090            Esomeprazole            20 mg  Mups Tablet  0  Human
# 35091            Esomeprazole            40 mg  Mups Tablet  0  Human
# 35092             Tirzepatide     2.5 mg/.5 ml    Injection  0  Human
# 35093             Tirzepatide       5 mg/.5 ml    Injection  0  Human
# 35094             Tirzepatide     7.5 mg/.5 ml    Injection  0  Human
#
#                   8
# 0      394-0001-023
# 1      394-0002-062
# 2      394-0003-065
# 3      394-0004-067
# 4      394-0005-046
# ...             ...
# 35090  242-0575-067
# 35091  242-0574-067
# 35092  242-0571-015
# 35093  242-0570-015
# 35094  242-0572-015
#
# [35095 rows x 8 columns]

# %%
allopathic_data.columns = ['Name_of_the_Manufecturer','Brand_Name','Generic_Name','Strength','Dosage_Description','Retail_Price','Used_For','DAR']

# %%
allopathic_data
# Out:
#          Name_of_the_Manufecturer                     Brand_Name  \
# 0          ACI HealthCare Limited                    Nimocon 500
# 1          ACI HealthCare Limited                          Adbon
# 2          ACI HealthCare Limited                     Opental 50
# 3          ACI HealthCare Limited                      Acidex 20
# 4          ACI HealthCare Limited                     Neutin 600
# ...                           ...                            ...
# 35090  Ziska Pharmaceuticals Ltd.                Esoprol 20 MUPS
# 35091  Ziska Pharmaceuticals Ltd.                Esoprol 40 MUPS
# 35092  Ziska Pharmaceuticals Ltd.   Tizaro2.5 Pre-filled Syringe
# 35093  Ziska Pharmaceuticals Ltd.    Tizaro 5 Pre-filled Syringe
# 35094  Ziska Pharmaceuticals Ltd.  Tizaro 7.5 Pre-filled Syringe
#
#                  Generic_Name         Strength Dosage_Description  \
# 0                Azithromycin           500 mg             Tablet
# 1        Calcium + Vitamin D3  500 mg + 200 IU             Tablet
# 2      Tramadol Hydrochloride            50 mg             Tablet
# 3                  Omeprazole            20 mg            Capsule
# 4                  Gabapentin           600 mg             Tablet
# ...                       ...              ...                ...
# 35090            Esomeprazole            20 mg        Mups Tablet
# 35091            Esomeprazole            40 mg        Mups Tablet
# 35092             Tirzepatide     2.5 mg/.5 ml          Injection
# 35093             Tirzepatide       5 mg/.5 ml          Injection
# 35094             Tirzepatide     7.5 mg/.5 ml          Injection
#
#       Retail_Price Used_For           DAR
# 0                0    Human  394-0001-023
# 1                0    Human  394-0002-062
# 2                0    Human  394-0003-065
# 3                0    Human  394-0004-067
# 4                0    Human  394-0005-046
# ...            ...      ...           ...
# 35090            0    Human  242-0575-067
# 35091            0    Human  242-0574-067
# 35092            0    Human  242-0571-015
# 35093            0    Human  242-0570-015
# 35094            0    Human  242-0572-015
#
# [35095 rows x 8 columns]

# %%
allopathic_data.describe()
# Out:
#             Name_of_the_Manufecturer           Brand_Name   Generic_Name  \
# count                          35095                35095          35095
# unique                           216                31368           1688
# top     Incepta Pharmaceuticals Ltd.  Water for Injection  Ciprofloxacin
# freq                            1335                   69            516
#
#        Strength Dosage_Description Retail_Price Used_For       DAR
# count     35095              35095        35095    35095     35095
# unique     1398                139         2972        3     34923
# top      500 mg             Tablet            0    Human  272--023
# freq       1969              16211        13333    33161         4

# %%
allopathic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35095 entries, 0 to 35094
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name_of_the_Manufecturer  35095 non-null  object
#  1   Brand_Name                35095 non-null  object
#  2   Generic_Name              35095 non-null  object
#  3   Strength                  35095 non-null  object
#  4   Dosage_Description        35095 non-null  object
#  5   Retail_Price              35095 non-null  object
#  6   Used_For                  35095 non-null  object
#  7   DAR                       35095 non-null  object
# dtypes: object(8)
# memory usage: 2.1+ MB

# %%
allopathic_data['Name_of_the_Manufecturer'].unique().shape
# Out:
# (216,)

# %%
allopathic_data['Name_of_the_Manufecturer'].unique()
# Out:
# array(['ACI HealthCare Limited', 'Active Fine Chemicals Ltd.',
#        'Ad-din Pharmaceuticals Ltd.', 'Adova Pharmaceuticals Ltd.',
#        'Advanced Chemical Industries Limited', 'Advent Pharma Ltd.',
#        'AFC Agro Biotech Ltd.', 'Al-Madina Pharmaceuticals Ltd.',
#        'Albion Laboratories Ltd.', 'Albion Specialized Pharma Limited',
#        'Alco Pharma Limited', 'Alkad Laboratories',
#        'Allied Pharmaceuticals Ltd.', 'Ambee Pharmaceuticals Ltd.',
#        'Amico Laboratories Ltd.', 'Amulet Pharmaceuticals Ltd.',
#        'APC Pharma Limited', 'Apex Pharma Ltd.',
#        'Apollo Pharmaceutical Laboratories Ltd.',
#        'Arges Life Science Ltd.', 'Aristopharma Limited',
#        'Aristopharma Limited, Gazipur', 'Army Pharma Limited',
#        'Asiatic Laboratories Ltd.', 'Astra Biopharmaceuticals Ltd.',
#        'Avarox Pharmaceuticals Ltd.', 'Aztec Pharmaceuticals Ltd.',
#        'Bangladesh Antibiotic Industries Limited',
#        'Beacon Cephalosporin Ltd.,', 'Beacon Pharmaceuticals PLC',
#        'Belsen Pharmaceuticals Ltd.',
#        'Bengal Drugs & Chemical Works Pharm. Ltd.',
#        'Bengal Remedies Ltd.', 'Benham Pharmaceuticals Ltd.',
#        'Beximco Pharmaceuticals Ltd.',
#        'Beximco Pharmaceuticals Ltd., Kaliakoir',
#        'Bexter Pharmaceuticals', 'Biogen Pharmaceuticals Ltd.',
#        'Biopharma Ltd.', 'Bridge Pharmaceuticals Ltd.',
#        'Bristol Pharma Ltd.', 'C2C Pharma Limited',
#        'Centeon Pharma Limited', 'Central Pharmaceutical Ltd.',
#        'Chemist Laboratories Ltd.', 'Cipla Ltd.',
#        'Concord Pharmaceuticals Ltd.', 'Cosmic Pharma Ltd.',
#        'Cosmo Pharma Laboratories Ltd.', 'DBL Pharmaceuticals Limited',
#        'Decent Pharma Laboratories Ltd.', 'Delta Pharma Limited',
#        'Desh Pharmaceuticals Ltd.', 'Dider Pharma Ltd.,',
#        'Doctor Tims Pharmaceuticals Ltd.',
#        "Doctor's Chemicals Works Ltd.", 'Drug International Ltd.',
#        'Drug International Ltd., Gopalpur',
#        'Drug International Ltd., Squib Road', 'EDCL (Bogra)',
#        'EDCL (Dhaka)', 'Edruc Ltd.', 'EMCS Pharma Limited',
#        'Eon Pharmaceuticals Ltd.',
#        'Eskayef Pharmaceuticals Ltd. Chandana, Gazipur',
#        'Eskayef Pharmaceuticals Ltd. Mirpur.',
#        'Eskayef Pharmaceuticals Ltd., Narayanganj',
#        'Eskayef Pharmaceuticals Ltd., Tongi,Gazipur', 'Ethical Drug Ltd.',
#        'Euro Pharma Ltd.', 'Everest Pharmaceuticals Ltd.',
#        'FnF Pharmaceuticals Ltd.', 'G. A. Company Ltd.',
#        'General Pharmaceuticals Ltd, Unit-2',
#        'General Pharmaceuticals Ltd.', 'Gentry Pharmaceuticals Ltd.',
#        'Genvio Pharma Ltd.', 'Get Well Limited', 'Global Capsules Ltd.',
#        'Global Capsules Ltd., Gelatin Division',
#        'Global Heavy Chemicals Ltd.', 'Globe Pharmaceuticals Ltd.',
#        'Globex Pharmaceuticals Ltd.', 'Gonoshasthaya Basic Chemical Ltd.',
#        'Gonoshasthaya Pharmaceuticals Ltd.',
#        'Goodman Pharmaceuticals Ltd', 'Greenland Pharmaceuticals Ltd.',
#        'Guardian Healthcare Ltd.', 'Healthcare Pharmaceuticals Ltd.',
#        'Hudson Pharmaceuticals Ltd.', 'Ibn Sina Pharmaceutical Ind. Ltd.',
#        'Incepta Pharmaceuticals Ltd.',
#        'Incepta Pharmaceuticals Ltd. (Dhamrai Unit)',
#        'Incepta Pharmaceuticals Ltd., Chemical Division',
#        'Incepta Pharmaceuticals Ltd., Vaccine Division',
#        'Indo-Bangla Pharmaceuticals Ltd.', 'Islam Oxygen (Pvt) Ltd.',
#        'Jayson Pharmaceuticals Ltd.', 'Jenphar Bangladesh Ltd.',
#        'JMI Industrial Gas Ltd.', 'JMI Syringes & Medical Devices Ltd.',
#        'JR Pharmaceuticals Ltd.', 'Kemiko Pharmaceuticals Ltd.',
#        'Kumudini Pharma Ltd.', 'Labaid Pharmaceuticals Ltd.',
#        'Leader Pharmaceuticals Limited', 'Leon Pharmaceuticals Ltd.',
#        'Libra Infusion Limited', 'Linde Bangladesh Limited',
#        'Maks Drugs Ltd.', 'Marksman Pharmaceutical Ltd.',
#        'Medicon Pharmaceuticals Ltd.', 'Medimet Pharmaceuticals Ltd.',
#        'MedRx Life Science Ltd.', 'Millat Pharmaceuticals Ltd.',
#        'Modern Pharmaceuticals Ltd.', 'Momtaz Pharmaceuticals Ltd.',
#        'Monicopharma Limited', 'MSF Pharmaceuticals Ltd.,',
#        'MST Pharma and Healthcare Ltd.',
#        'Mundipharma (Bangladesh) Pvt. Ltd.',
#        'Mystic Pharmaceuticals Ltd.', 'Naafco Pharma Ltd.',
#        'National Drug Company Ltd.', 'National Laboratories Ltd.',
#        'Navana Pharmaceuticals Ltd.', 'Newtec Pharmaceuticals Ltd.',
#        'Nip Chemicals And Pharmaceuticals Ltd.',
#        'Nipa Pharmaceuticals Ltd.', 'NIPRO JMI Company Ltd.',
#        'NIPRO JMI Pharma Limited', 'Novartis  (Bangladesh) Ltd.',
#        'Novatek Pharmaceuticals Ltd.', 'Novo Healthcare and Pharma Ltd.',
#        'Novo Healthcare and Pharma Ltd. (Unit-2)',
#        'Novus Pharmaceuticals Ltd.', 'Nuvista Pharma Ltd',
#        'One Pharma Ltd.', 'Opsonin Bulk Drugs Ltd.',
#        'Opsonin Pharma Limited', 'Orion Infusion Ltd.',
#        'Orion Pharma Ltd.', 'OSL Pharma Ltd.',
#        'Oyster Pharmaceuticals Ltd.', 'Pacific Pharmaceuticals Ltd.',
#        'Peoples Pharma Ltd.', 'Pharmacil Ltd.', 'Pharmasia Ltd.',
#        'Pharmatek Chemicals Ltd.', 'Pharmik Laboratories Ltd.',
#        'Physic Pharmaceuticals Ltd.,', 'Popular Pharmaceuticals Ltd.',
#        'Premier Pharmaceuticals Ltd.', 'Prime Pharmaceuticals Ltd.',
#        'Pristine Chem Limited', 'Pristine Pharmaceuticals',
#        'Purbadesh Chemists Ltd.,', 'Quality Pharmaceuticals (Pvt) Ltd.',
#        'Radiant Pharmaceuticals Ltd.', 'Rahman Chemicals Ltd.',
#        'Rampart-Power Bangladesh Ltd.', 'Rangs Pharmaceuticals Ltd.',
#        'Reckitt Benckiser Bangladesh Ltd.',
#        'Reliance Pharmaceuticals Ltd.', 'Reman Drug Laboratories Ltd.',
#        'Remo Chemical Ltd.', 'Renata Limited', 'Renata Limited, Gazipur',
#        'Renata Ltd., Bhaluka', 'Rephco Pharmaceuticals Ltd.',
#        'RN Pharmaceuticals', 'Royal Pharmaceuticals Ltd.',
#        'S. N. Pharmaceuticals Ltd.', 'Save Pharmaceuticals Ltd.',
#        'Seba Laboratories Ltd.', 'Sharif Pharmaceuticals Ltd.',
#        'Shinil Pharma Limited', 'Silco Pharmaceuticlas Ltd.',
#        'Silva Pharmaceuticals Ltd.', 'SMC Enterprise Limited',
#        'Sodical Chemical Ltd.', 'Somatec Pharmaceuticals Ltd.',
#        'Spectra International Ltd.,', 'Spectra Oxygen Limited',
#        'Square Cephalosporins Ltd.', 'Square Formulations Ltd.',
#        'Square Lifesciences Limited, Pabna',
#        'Square Pharmaceuticals PLC, (Chemical Division)',
#        'Square Pharmaceuticals PLC, Gazipur',
#        'Square Pharmaceuticals PLC, Pabna', 'Standard Laboratories Ltd.',
#        'Sun Pharmaceutical (Bangladesh) Ltd.',
#        'Sunman-Birdem Pharma Ltd.', 'Super Power Pharmaceuticals Ltd.',
#        'Supreme Pharmaceuticals Ltd.', 'Synovia Pharma PLC.',
#        'Team Pharmaceuticals Ltd.', 'Techno Drugs (Unit-3)',
#        'Techno Drugs Ltd.', 'Techno Drugs Ltd., Gazipur',
#        'The ACME Laboratories Ltd.',
#        'The White Horse Pharmaceuticals Ltd.',
#        'UNIDO Pharmaceuticals Ltd.',
#        'Unimed Unihealth Pharmaceuticals Ltd.', 'Union Oxygen Limited',
#        'Union Pharmaceuticals Ltd.', 'Unique Pharmaceutical Ltd.',
#        'United Chemicals & Pharmaceuticals Ltd.',
#        'Veritas Pharmaceuticals Ltd.',
#        'Vion Pharmaceuticals (Veterinary)', 'Virgo Pharmaceuticals Ltd.',
#        'Vision Drugs Limited (Veterinary)',
#        'World API Chemical Industry Ltd.', 'Zenith Pharmaceuticals Ltd.',
#        'Zhaofeng Gelating Limited', 'Ziska Pharmaceuticals Ltd.'],
#       dtype=object)

# %% [markdown]
# #### Total manufecturers, medicine brands, generics and registered drug counts

# %%
print('TOTAL MANUFECTURERS COUNT: ', len(allopathic_data['Name_of_the_Manufecturer'].unique()))
# Out:
# TOTAL MANUFECTURERS COUNT:  216

# %%
print('TOTAL BRANDS COUNT: ', len(allopathic_data['Brand_Name'].unique()))
# Out:
# TOTAL BRANDS COUNT:  31368

# %%
print('TOTAL REGISTERED DRUGS COUNT: ', len(allopathic_data['DAR'].unique()))
# Out:
# TOTAL REGISTERED DRUGS COUNT:  34923

# %%
print('TOTAL GENERICS COUNT: ', len(allopathic_data['Generic_Name'].unique()))
# Out:
# TOTAL GENERICS COUNT:  1688

# %%
allopathic_data.head(6)
# Out:
#   Name_of_the_Manufecturer   Brand_Name            Generic_Name  \
# 0   ACI HealthCare Limited  Nimocon 500            Azithromycin
# 1   ACI HealthCare Limited        Adbon    Calcium + Vitamin D3
# 2   ACI HealthCare Limited   Opental 50  Tramadol Hydrochloride
# 3   ACI HealthCare Limited    Acidex 20              Omeprazole
# 4   ACI HealthCare Limited   Neutin 600              Gabapentin
# 5   ACI HealthCare Limited   AFDC-2 F/C  Isoniazid + Rifampicin
#
#           Strength Dosage_Description Retail_Price Used_For           DAR
# 0           500 mg             Tablet            0    Human  394-0001-023
# 1  500 mg + 200 IU             Tablet            0    Human  394-0002-062
# 2            50 mg             Tablet            0    Human  394-0003-065
# 3            20 mg            Capsule            0    Human  394-0004-067
# 4           600 mg             Tablet            0    Human  394-0005-046
# 5   75 mg + 150 mg             Tablet      6.00 Tk    Human  394-0007-030

# %% [markdown]
# ####  Removing non-digit and non-dot characters & converting the price column to numeric type

# %%
allopathic_data['Retail_Price'] = allopathic_data['Retail_Price'].str.replace('[^\d.]', '', regex=True)

# %%
allopathic_data['Retail_Price'] = pd.to_numeric(allopathic_data['Retail_Price'])

# %%
allopathic_data.head(6)
# Out:
#   Name_of_the_Manufecturer   Brand_Name            Generic_Name  \
# 0   ACI HealthCare Limited  Nimocon 500            Azithromycin
# 1   ACI HealthCare Limited        Adbon    Calcium + Vitamin D3
# 2   ACI HealthCare Limited   Opental 50  Tramadol Hydrochloride
# 3   ACI HealthCare Limited    Acidex 20              Omeprazole
# 4   ACI HealthCare Limited   Neutin 600              Gabapentin
# 5   ACI HealthCare Limited   AFDC-2 F/C  Isoniazid + Rifampicin
#
#           Strength Dosage_Description  Retail_Price Used_For           DAR
# 0           500 mg             Tablet           0.0    Human  394-0001-023
# 1  500 mg + 200 IU             Tablet           0.0    Human  394-0002-062
# 2            50 mg             Tablet           0.0    Human  394-0003-065
# 3            20 mg            Capsule           0.0    Human  394-0004-067
# 4           600 mg             Tablet           0.0    Human  394-0005-046
# 5   75 mg + 150 mg             Tablet           6.0    Human  394-0007-030

# %%
allopathic_data[(allopathic_data['Dosage_Description']=='Injection') & (allopathic_data['Used_For']=='Human')]
# Out:
#           Name_of_the_Manufecturer                     Brand_Name  \
# 178    Ad-din Pharmaceuticals Ltd.                    Somazole IV
# 179    Ad-din Pharmaceuticals Ltd.                    Lacor IM/IV
# 180    Ad-din Pharmaceuticals Ltd.                     Tium IV/IM
# 182    Ad-din Pharmaceuticals Ltd.             Sodium Chloride.9%
# 186    Ad-din Pharmaceuticals Ltd.                      Admero IV
# ...                            ...                            ...
# 35027   Ziska Pharmaceuticals Ltd.               Derisofer 100 iv
# 35067   Ziska Pharmaceuticals Ltd.                       Oxyto DS
# 35092   Ziska Pharmaceuticals Ltd.   Tizaro2.5 Pre-filled Syringe
# 35093   Ziska Pharmaceuticals Ltd.    Tizaro 5 Pre-filled Syringe
# 35094   Ziska Pharmaceuticals Ltd.  Tizaro 7.5 Pre-filled Syringe
#
#                    Generic_Name      Strength Dosage_Description  \
# 178                Esomeprazole    40 mg/vial          Injection
# 179      Ketorolac Tromethamine      30 mg/ml          Injection
# 180    Tiemonium Methylsulphate     2.5 mg/ml          Injection
# 182             Sodium Chloride       9 mg/ml          Injection
# 186                   Meropenem   500 mg/vial          Injection
# ...                         ...           ...                ...
# 35027     Ferric Carboxymaltose   100 mg/2 ml          Injection
# 35067                  Oxytocin      10 IU/ml          Injection
# 35092               Tirzepatide  2.5 mg/.5 ml          Injection
# 35093               Tirzepatide    5 mg/.5 ml          Injection
# 35094               Tirzepatide  7.5 mg/.5 ml          Injection
#
#        Retail_Price Used_For           DAR
# 178             0.0    Human  084-0191-067
# 179             0.0    Human  084-0192-064
# 180             0.0    Human  084-0193-011
# 182             0.0    Human  084-0195-079
# 186             0.0    Human  084-0202-023
# ...             ...      ...           ...
# 35027           0.0    Human  242-0425-045
# 35067           0.0    Human  242-0496-049
# 35092           0.0    Human  242-0571-015
# 35093           0.0    Human  242-0570-015
# 35094           0.0    Human  242-0572-015
#
# [2409 rows x 8 columns]

# %%
import seaborn as sns
sns.barplot(data=allopathic_data, x="Used_For", y="Retail_Price")
# Out:
# <AxesSubplot:xlabel='Used_For', ylabel='Retail_Price'>

# %% [markdown]
# ## Top manufecturers

# %%
grouped_data = allopathic_data.groupby('Name_of_the_Manufecturer')

# %% [markdown]
# #### Based on the total retail price

# %%
manufacturer_totals = grouped_data['Retail_Price'].sum()

# %%
sorted_manufacturers = manufacturer_totals.sort_values(ascending=False)
top_manufacturers = sorted_manufacturers.head(10)
top_manufacturers
# Out:
# Name_of_the_Manufecturer
# Popular Pharmaceuticals Ltd.                   6.309579e+09
# Al-Madina Pharmaceuticals Ltd.                 6.272408e+09
# Albion Laboratories Ltd.                       6.263812e+09
# Guardian Healthcare Ltd.                       5.883204e+09
# Everest Pharmaceuticals Ltd.                   5.406131e+09
# Renata Limited                                 5.402539e+09
# Incepta Pharmaceuticals Ltd. (Dhamrai Unit)    5.150521e+09
# Advanced Chemical Industries Limited           4.853851e+09
# The ACME Laboratories Ltd.                     4.659309e+09
# Newtec Pharmaceuticals Ltd.                    4.620800e+09
# Name: Retail_Price, dtype: float64

# %% [markdown]
# #### Based on count of entries for each manufecturer

# %%
manufacturer_counts = grouped_data.size()
sorted_manufacturers = manufacturer_counts.sort_values(ascending=False)
top_manufacturers = sorted_manufacturers.head(10)
top_manufacturers
# Out:
# Name_of_the_Manufecturer
# Incepta Pharmaceuticals Ltd.                   1335
# Opsonin Pharma Limited                         1237
# Square Pharmaceuticals PLC, Pabna              1227
# The ACME Laboratories Ltd.                     1032
# Advanced Chemical Industries Limited           1018
# Beximco Pharmaceuticals Ltd.                   1006
# Renata Limited                                  864
# Eskayef Pharmaceuticals Ltd., Tongi,Gazipur     710
# Aristopharma Limited                            705
# Popular Pharmaceuticals Ltd.                    704
# dtype: int64
